# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
# %matplotlib inline

# prosperloan_data = pd.read_csv('prosperLoanData.csv')
# prosperloan_data.head()
baseball_data = pd.read_csv('baseball_data.csv')
baseball_data.head()
# Out:
#              name handedness  height  weight    avg   HR
# 0       Tom Brown          R      73     170  0.000    0
# 1  Denny Lemaster          R      73     182  0.130    4
# 2       Joe Nolan          L      71     175  0.263   27
# 3     Denny Doyle          L      69     175  0.250   16
# 4   Jose Cardenal          R      70     150  0.275  138

# %%
baseball_data
# Out:
#                    name handedness  height  weight    avg   HR
# 0             Tom Brown          R      73     170  0.000    0
# 1        Denny Lemaster          R      73     182  0.130    4
# 2             Joe Nolan          L      71     175  0.263   27
# 3           Denny Doyle          L      69     175  0.250   16
# 4         Jose Cardenal          R      70     150  0.275  138
# 5             Mike Ryan          R      74     205  0.193   28
# 6        Fritz Peterson          B      72     185  0.159    2
# 7          Dick Bertell          R      72     200  0.250   10
# 8            Rod Kanehl          R      73     180  0.241    6
# 9          Ozzie Osborn          R      74     195  0.000    0
# 10          John LaRose          L      73     185  0.000    0
# 11            Jeff Byrd          R      75     195  0.000    0
# 12         Juan Bonilla          R      69     170  0.256    7
# 13       Frank Tepedino          L      71     185  0.241    6
# ...

# %%
baseball_data.describe()
# Out:
#             height       weight          avg           HR
# count  1157.000000  1157.000000  1157.000000  1157.000000
# mean     72.756266   184.513397     0.186793    45.359551
# std       2.142272    15.445995     0.106175    74.065110
# min      65.000000   140.000000     0.000000     0.000000
# 25%      71.000000   175.000000     0.138000     1.000000
# 50%      73.000000   185.000000     0.238000    15.000000
# 75%      74.000000   195.000000     0.258000    55.000000
# max      80.000000   245.000000     0.328000   563.000000

# %%
baseball_data.columns
# Out:
# Index([u'name', u'handedness', u'height', u'weight', u'avg', u'HR'], dtype='object')

# %%
sample_data = baseball_data[['handedness','height','weight','avg','HR']]

# %%
sample_data
# Out:
#      handedness  height  weight    avg   HR
# 0             R      73     170  0.000    0
# 1             R      73     182  0.130    4
# 2             L      71     175  0.263   27
# 3             L      69     175  0.250   16
# 4             R      70     150  0.275  138
# 5             R      74     205  0.193   28
# 6             B      72     185  0.159    2
# 7             R      72     200  0.250   10
# 8             R      73     180  0.241    6
# 9             R      74     195  0.000    0
# 10            L      73     185  0.000    0
# 11            R      75     195  0.000    0
# 12            R      69     170  0.256    7
# 13            L      71     185  0.241    6
# 14            L      73     175  0.000    0
# 15            R      73     180  0.195   15
# 16            L      74     200  0.248  414
# 17            R      70     190  0.225   58
# 18            R      72     190  0.262   86
# 19            L      72     183  0.246   75
# ...
